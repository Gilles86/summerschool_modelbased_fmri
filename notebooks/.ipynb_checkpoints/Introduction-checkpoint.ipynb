# %%
import numpy as np

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-2b1da000a957> in <module>()
# ----> 1 get_ipython().magic(u'matplotlib inline')
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2161         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2162         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2163         return self.run_line_magic(magic_name, magic_arg_s)
#    2164
#    2165     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2082                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2083             with self.builtin_trap:
# -> 2084                 result = fn(*args,**kwargs)
#    2085             return result
#    2086
#
# <decorator-gen-106> in matplotlib(self, line)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.pyc in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in enable_matplotlib(self, gui)
#    2937         """
#    2938         from IPython.core import pylabtools as pt
# -> 2939         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2940
#    2941         if gui != 'inline':
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in find_gui_and_backend(gui, gui_select)
#     258     """
#     259
# --> 260     import matplotlib
#     261
#     262     if gui and gui != 'auto':
#
# ImportError: No module named matplotlib

# %% [markdown]
# # Simple Python

# %%
a = 1

# %%
a
# Out:
# 1

# %%
b = [1,2,3]

# %%
b
# Out:
# [1, 2, 3]

# %%
for element in b:
    print element
# Out:
# 1
# 2
# 3

# %%
b[1:3]
# Out:
# [2, 3]

# %%
b[0]
# Out:
# 1

# %%
c = np.array(b)

# %%
c
# Out:
# array([1, 2, 3])

# %%
c * np.arange(3)
# Out:
# array([0, 2, 6])

# %%
c.dot(np.arange(3).T)
# Out:
# 8

# %% [markdown]
# # Numpy/scipy

# %%
np.random.randn(100, 10)
# Out:
# array([[ -9.18983700e-01,   5.36772911e-01,  -5.59885623e-01,
#           1.28785598e-01,   4.27926404e-01,   5.17081692e-01,
#          -5.53493301e-01,   5.70470756e-01,  -2.26267388e-01,
#          -3.26928939e-01],
#        [ -5.87763402e-01,  -4.08341913e-02,  -2.35991104e-01,
#           1.76583680e+00,  -4.95324381e-02,  -3.02181418e-02,
#           2.93785159e+00,  -7.83792040e-01,  -2.23089379e-01,
#           7.07492441e-01],
#        [ -6.72325879e-01,   1.35197663e+00,   8.12353711e-01,
#           1.24346270e-01,   9.68026113e-01,  -1.36066563e+00,
#          -1.42818598e+00,   2.78208692e-01,   6.17382173e-01,
#          -2.42581687e-01],
#        [  5.01850471e-01,   4.36975806e-01,   1.08497222e+00,
#          -1.17528032e+00,  -8.27796353e-01,   1.00849194e-01,
#           1.12263740e-01,  -2.37315842e+00,   6.84593111e-01,
#           6.89301091e-01],
#        [  4.99305537e-01,  -3.44265726e-01,  -9.18984231e-02,
#           5.73786591e-01,   1.12633929e+00,   9.80085118e-01,
#          -1.53240517e+00,   1.56184907e-01,   8.52330660e-02,
#          -9.99707739e-01],
#        [  5.35211062e-01,  -1.29323218e+00,   2.20040337e+00,
#          -2.16689379e-01,   9.13631878e-01,   1.86518798e+00,
#           6.80794932e-01,  -5.04264196e-01,   4.63434575e-01,
#          -8.53428861e-01],
#        [ -1.42325237e+00,  -1.08460387e+00,  -2.33253892e+00,
#           1.30407508e-01,  -4.34467084e-01,  -7.00598245e-01,
# Out:
# array([ 0,  1,  4,  9, 16])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(np.random.randn(100, 100), cmap=plt.cm.hot)

# %%
t = np.linspace(0, 3, 100)

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/computation/__init__.py:25: UserWarning: The installed version of numexpr 1.4.2 is not supported in pandas and will be not be used
# The minimum supported version is 2.1
#
#   "version is 2.1\n".format(ver=ver), UserWarning)
# /usr/local/lib/python2.7/dist-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
sns.set_style('white')

# %%
plt.plot(t, t**2)
sns.despine()

# %% [markdown]
# # Logistic function
#
#
# The following function implements the logistic function:
# $f(x) = \frac{1}{1 + e^{-k(x - x0)}}$

# %%
def logistic(x, x0=0, k=1.):
    return 1 / (1 + np.exp(-k * (x - x0)))

# %%
logistic(-1)
# Out:
# 0.2689414213699951

# %%
t = np.linspace(-3, 3, 100)


for k in [1, 2, 3]:
    plt.plot(t, logistic(t, k=k), label='k = %s' % k)

plt.legend(loc='lower right')
    
plt.axhline(.5, c='k', ls='--')

# %%
t = np.linspace(-3, 3, 100)


for x0 in [0, .5, -.5]:
    plt.plot(t, logistic(t, x0=x0), label='x0 = %s' % k)

plt.legend(loc='lower right')
    
plt.axhline(.5, c='k', ls='--')

# %%
# x = np.array([])
x = np.linspace(-5, 5, 10)

x0 = .2
k = 1

y = logistic(x, x0, k) + np.random.randn(len(x)) * .1


plt.scatter(x, y)

plt.plot(t, logistic(t, x0, k))

plt.axhline(.5, c='k', ls='--')

# %%
def logistic_cost(pars, x,  y):
    
    x0, k = pars
    
    predictions = logistic(x, x0, k)
    
    return np.sum((y - predictions) ** 2)

# %%
import scipy as sp

# %%
sns.set_context('poster')

# %%
x = np.array([0, 1, 2., 3, .5])

x0 = .5
k = 2.

x = np.array([0, 1, 2., 3, .5])
samples = logistic(x, x0=x0, k=k) + np.random.randn(len(x)) * .1

plt.scatter(x, samples)

plt.plot(t, logistic(t, x0, k), c='k', alpha=.5)

x0_, k_ = sp.optimize.fmin(logistic_cost, [0, 1], (x, samples))

plt.plot(t, logistic(t, x0_, k_), ls='--', c='k', alpha=.5)

sns.despine()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.054023
#          Iterations: 51
#          Function evaluations: 93

# %%
import pymc
import numpy as np

# %%
x = np.linspace(-5, 5, 10)
x0 = .5
k = 1.

samples = logistic(x, x0=x0, k=k) + np.random.randn(len(x)) * .1

plt.scatter(x, samples)

x_ = np.linspace(-4, 4, 100)
plt.plot(x_, logistic(x_, x0, k))

# %%
k_prior = pymc.Normal('k', 0, 1.)
x0_prior = pymc.Normal('x0', 0, 1.)

# %%
@pymc.stochastic(observed=True)
def logistic_likelihood(value=samples, k=k_prior, x0=x0_prior, x=x):
    
    predictions = logistic(x, x0, k)
    
    residuals = predictions - value
    
    return pymc.normal_like(residuals, residuals.mean(), 1/residuals.std())

# %%
model = pymc.Model([k_prior, x0_prior, logistic_likelihood])

# %%
#Make a slightly pretty graph out of it
graph = pymc.graph.graph(model)
graph.write_png("graph.png")
# Out:
# True

# %%
from IPython.display import Image

# %%
Image('graph.png')

# %%
sampler = pymc.MCMC(model, db='ram')

# %%
sampler.sample(5000)
# Out:
#  [-----------------100%-----------------] 5000 of 5000 complete in 0.9 sec

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
sampler.trace('x0')[:].mean(), sampler.trace('k')[:].mean()
# Out:
# (0.61635089768201456, 1.100637340080618)

# %%
plt.hist(sampler.trace('x0')[:])
# Out:
# (array([    5.,    31.,   124.,   335.,   949.,  1494.,  1305.,   546.,
#           179.,    32.]),
#  array([-1.88894882, -1.44781174, -1.00667465, -0.56553757, -0.12440049,
#          0.31673659,  0.75787367,  1.19901075,  1.64014783,  2.08128491,
#          2.522422  ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns

# %%
sns.distplot(sampler.trace('k')[:])

plt.axvline(sampler.trace('k')[:].mean(), c='k')
plt.axvline(k, c='k', ls='--')

# %%
sns.distplot(sampler.trace('x0')[:])

plt.axvline(sampler.trace('x0')[:].mean(), c='k')
plt.axvline(x0, c='k', ls='--')

# %%
k_traces = sampler.trace('k')[:]
x0_traces = sampler.trace('x0')[:]

# %%
plt.figure(figsize=(15, 10))

x_ = np.linspace(-4, 4, 100)


for i in np.arange(4000, 5000, 3):
    plt.plot(x_, logistic(x_, x0_traces[i], k_traces[i]), c='k', alpha=0.01)
    
plt.scatter(x, samples, c='r', s=100)

# %% [markdown]
# # Behavior

# %%
# !ls /data
# Out:
# behavior.pandas  func_raw  mask  struct  tdcs_data.csv

# %%
import pandas

# %%
df = pandas.read_csv('/data/tdcs_data.csv')
df.shape
# Out:
# (52200, 12)

# %%
df.describe()
# Out:
#                  RT      accuracy    angle         block     coherence  \
# count  52200.000000  52200.000000  52200.0  52200.000000  52200.000000
# mean     573.639885      0.729732    180.0      1.505747      0.217459
# std      225.551916      0.444103      0.0      0.499972      0.088321
# min        0.000000      0.000000    180.0      1.000000      0.065300
# 25%      426.000000      0.000000    180.0      1.000000      0.155800
# 50%      519.000000      1.000000    180.0      2.000000      0.206000
# 75%      667.000000      1.000000    180.0      2.000000      0.276400
# max     2013.000000      1.000000    180.0      2.000000      0.417100
#
#          left_right      subj_idx      trial_NR
# count  52200.000000  52200.000000  52200.000000
# mean       1.500000      8.655172    300.500000
# std        0.500005      4.517767    173.206499
# min        1.000000      1.000000      1.000000
# 25%        1.000000      5.000000    150.750000
# 50%        1.500000      9.000000    300.500000
# 75%        2.000000     13.000000    450.250000
# max        2.000000     17.000000    600.000000

# %%
sns.distplot(df.ix[(df.dataset == 'berkeley') & (df.subj_idx == 2) & (df.acc_spd == 'spd')].RT, bins=20, color='r')
sns.distplot(df.ix[(df.dataset == 'berkeley') & (df.subj_idx == 2) & (df.acc_spd == 'acc')].RT, bins=20, color='g')

# %% [markdown]
# # split-apply-combine

# %%
df.groupby('acc_spd').mean()
# Out:
#                  RT  accuracy  angle     block  coherence  left_right  \
# acc_spd
# acc      646.669585  0.762547  180.0  1.505741   0.217812    1.502784
# spd      500.928470  0.697060  180.0  1.505754   0.217107    1.497228
#
#          subj_idx    trial_NR
# acc_spd
# acc      8.643321  302.479246
# spd      8.666973  298.529380

# %%
np.round(df.groupby(['dataset', 'acc_spd']).mean()[['RT', 'accuracy']], 2)
# Out:
#                        RT  accuracy
# dataset   acc_spd
# amsterdam acc      640.40      0.76
#           spd      522.00      0.71
# berkeley  acc      622.02      0.77
#           spd      482.71      0.71
# leiden    acc      678.60      0.76
#           spd      497.56      0.67

# %%
df_subj = df.groupby(['subj_idx', 'dataset', 'tdcs', 'acc_spd'], as_index=False).mean()

# %%
np.round(df.groupby(['dataset', 'tdcs', 'acc_spd']).agg([np.mean, np.std])[['RT', 'accuracy']], 2)
# Out:
#                               RT         accuracy
#                             mean     std     mean   std
# dataset   tdcs   acc_spd
# amsterdam anodal acc      646.14  232.79     0.76  0.43
#                  spd      526.44  178.83     0.70  0.46
#           sham   acc      634.63  236.40     0.76  0.43
#                  spd      517.58  173.58     0.71  0.45
# berkeley  anodal acc      602.48  228.13     0.75  0.43
#                  spd      476.82  166.69     0.71  0.46
#           sham   acc      643.46  246.00     0.79  0.41
#                  spd      488.88  150.08     0.72  0.45
# leiden    anodal acc      681.48  268.51     0.75  0.43
#                  spd      505.94  172.02     0.67  0.47
#           sham   acc      675.74  281.22     0.77  0.42
#                  spd      489.15  164.19     0.67  0.47

# %%
df_subj = df.groupby(['subj_idx', 'dataset', 'tdcs', 'acc_spd'], as_index=False).mean()

df_subj.head(10)
# Out:
#    subj_idx    dataset    tdcs acc_spd          RT  accuracy  angle  block  \
# 0         1   berkeley  anodal     acc  461.837288  1.000000  180.0    2.0
# 1         1   berkeley  anodal     spd  443.265574  0.996721  180.0    2.0
# 2         1     leiden  anodal     acc  789.293729  0.960396  180.0    1.0
# 3         1     leiden  anodal     spd  547.451178  0.902357  180.0    1.0
# 4         1     leiden    sham     acc  727.930159  0.977778  180.0    2.0
# 5         1     leiden    sham     spd  483.508772  0.873684  180.0    2.0
# 6         2  amsterdam  anodal     acc  784.335423  0.699060  180.0    1.0
# 7         2  amsterdam  anodal     spd  500.309609  0.572954  180.0    1.0
# 8         2  amsterdam    sham     acc  773.409677  0.729032  180.0    2.0
# 9         2  amsterdam    sham     spd  486.882759  0.613793  180.0    2.0
#
#    coherence  left_right    trial_NR
# 0     0.4171    1.494915  290.972881
# 1     0.4171    1.504918  309.714754
# 2     0.2864    1.511551  310.181518
# 3     0.2864    1.488215  290.622896
# 4     0.2864    1.501587  307.838095
# 5     0.2864    1.498246  292.389474
# 6     0.2261    1.476489  301.887147
# 7     0.2261    1.526690  298.925267
# 8     0.2261    1.477419  303.032258
# 9     0.2261    1.524138  297.793103

# %%
df_subj.groupby(['dataset', 'tdcs', 'acc_spd']).agg([np.mean, np.std])[['RT', 'accuracy']]
# Out:
#                                   RT              accuracy
#                                 mean         std      mean       std
# dataset   tdcs   acc_spd
# amsterdam anodal acc      645.792239   94.415129  0.757666  0.114388
#                  spd      526.337169   68.344288  0.701475  0.095034
#           sham   acc      633.407696   92.270336  0.759489  0.100151
#                  spd      518.089836   56.332272  0.709534  0.113810
# berkeley  anodal acc      601.424115  125.768931  0.753072  0.112101
#                  spd      479.204293   99.410248  0.707868  0.112450
#           sham   acc      642.505276  110.602028  0.787193  0.075783
#                  spd      488.597690   65.610475  0.720669  0.056623
# leiden    anodal acc      681.992505  132.734350  0.751711  0.181006
#                  spd      506.690529   69.802201  0.666232  0.128057
#           sham   acc      674.465448  195.125856  0.766307  0.157853
#                  spd      490.338682   98.731230  0.676676  0.127185

# %%
for g, d in df.groupby(['dataset', 'subj_idx', 'acc_spd']):
    print g, d.RT.mean()
# Out:
# ('amsterdam', 2, 'acc') 778.950715421
# ('amsterdam', 2, 'spd') 493.490367776
# ('amsterdam', 3, 'acc') 612.182741117
# ('amsterdam', 3, 'spd') 494.05090312
# ('amsterdam', 4, 'acc') 690.91954023
# ('amsterdam', 4, 'spd') 627.697123519
# ('amsterdam', 5, 'acc') 511.988764045
# ('amsterdam', 5, 'spd') 432.604852686
# ('amsterdam', 6, 'acc') 581.721283784
# ('amsterdam', 6, 'spd') 445.613486842
# ('amsterdam', 7, 'acc') 685.942622951
# ('amsterdam', 7, 'spd') 553.827118644
# ('amsterdam', 8, 'acc') 579.300500835
# ('amsterdam', 8, 'spd') 498.916805324
# ('amsterdam', 10, 'acc') 533.548275862
# ('amsterdam', 10, 'spd') 523.564516129
# ('amsterdam', 11, 'acc') 550.684931507
# ('amsterdam', 11, 'spd') 471.581168831
# ('amsterdam', 12, 'acc') 694.846889952
# ('amsterdam', 12, 'spd') 615.497382199
# ('amsterdam', 13, 'acc') 670.085470085
# ('amsterdam', 13, 'spd') 535.889430894
# ('amsterdam', 14, 'acc') 578.37520938
# ('amsterdam', 14, 'spd') 542.907131012
# ('amsterdam', 15, 'acc') 689.220367279
# ('amsterdam', 15, 'spd') 467.317803661
# ('amsterdam', 16, 'acc') 633.418719212
# ('amsterdam', 16, 'spd') 560.384094755
# ('amsterdam', 17, 'acc') 800.008210181
# ('amsterdam', 17, 'spd') 571.930626058
# ('berkeley', 1, 'acc') 461.837288136
# ('berkeley', 1, 'spd') 443.26557377
# ('berkeley', 2, 'acc') 587.698142415
# ('berkeley', 2, 'spd') 558.916967509
# ('berkeley', 3, 'acc') 461.564784053
# ('berkeley', 3, 'spd') 404.476588629
# ('berkeley', 4, 'acc') 565.450980392
# ('berkeley', 4, 'spd') 389.856025039
# ('berkeley', 5, 'acc') 424.410211268
# ('berkeley', 5, 'spd') 410.311708861
# ('berkeley', 6, 'acc') 643.989690722
# ('berkeley', 6, 'spd') 580.572815534
# ('berkeley', 7, 'acc') 593.21858864
# ('berkeley', 7, 'spd') 504.982229402
# ('berkeley', 8, 'acc') 613.626029654
# ('berkeley', 8, 'spd') 465.959527825
# ('berkeley', 9, 'acc') 622.966273187
# ('berkeley', 9, 'spd') 494.23723229
# ('berkeley', 10, 'acc') 833.609715243
# ('berkeley', 10, 'spd') 646.399668325
# ('berkeley', 11, 'acc') 671.726495726
# ('berkeley', 11, 'spd') 576.227642276
# ('berkeley', 12, 'acc') 674.678868552
# ('berkeley', 12, 'spd') 399.801335559
# ('berkeley', 13, 'acc') 811.712837838
# ('berkeley', 13, 'spd') 492.542763158
# ('berkeley', 14, 'acc') 586.896243292
# ('berkeley', 14, 'spd') 419.08424337
# ('berkeley', 15, 'acc') 684.253611557
# ('berkeley', 15, 'spd') 445.644714038
# ('leiden', 1, 'acc') 758.01618123
# ('leiden', 1, 'spd') 516.139175258
# ('leiden', 2, 'acc') 746.641541039
# ('leiden', 2, 'spd') 552.150912106
# ('leiden', 3, 'acc') 701.527210884
# ('leiden', 3, 'spd') 510.687908497
# ('leiden', 4, 'acc') 460.503460208
# ('leiden', 4, 'spd') 429.92926045
# ('leiden', 5, 'acc') 878.452302632
# ('leiden', 5, 'spd') 578.83277027
# ('leiden', 7, 'acc') 582.350906096
# ('leiden', 7, 'spd') 537.802698145
# ('leiden', 8, 'acc') 491.174629325
# ('leiden', 8, 'spd') 483.053962901
# ('leiden', 9, 'acc') 656.394295302
# ('leiden', 9, 'spd') 383.430463576
# ('leiden', 10, 'acc') 491.531400966
# ('leiden', 10, 'spd') 463.008635579
# ('leiden', 11, 'acc') 905.506578947
# ('leiden', 11, 'spd') 573.9375
# ('leiden', 12, 'acc') 845.144480519
# ('leiden', 12, 'spd') 669.534246575
# ('leiden', 13, 'acc') 736.101754386
# ('leiden', 13, 'spd') 487.128571429
# ('leiden', 14, 'acc') 474.934533552
# ('leiden', 14, 'spd') 428.276740238
# ('leiden', 15, 'acc') 771.403087479
# ('leiden', 15, 'spd') 363.967585089

# %%
import seaborn as sns

# %%
sns.factorplot('acc_spd', 'RT', data=df)

# %%
sns.factorplot('acc_spd', 'RT', data=df, units='subj_idx')

# %%
sns.factorplot('acc_spd', 'RT', 'tdcs', data=df, units='subj_idx')

# %%
sns.factorplot('acc_spd', 'RT', 'tdcs', data=df, units='subj_idx', col='dataset')

# %%
# %load_ext rpy2.ipython

# %%
# %%R -i df
#
# print(head(df))
#
# library(BayesFactor)
# Out:
#    RT acc_spd accuracy angle block coherence  dataset   id left_right subj_idx
# 0 467     spd        1   180     2    0.4171 berkeley S1.2          1        1
# 1 427     acc        1   180     2    0.4171 berkeley S1.2          2        1
# 2 440     acc        1   180     2    0.4171 berkeley S1.2          1        1
# 3 454     acc        1   180     2    0.4171 berkeley S1.2          2        1
# 4 400     acc        1   180     2    0.4171 berkeley S1.2          1        1
# 5 414     acc        1   180     2    0.4171 berkeley S1.2          2        1
#     tdcs trial_NR
# 0 anodal        1
# 1 anodal        2
# 2 anodal        3
# 3 anodal        4
# 4 anodal        5
# 5 anodal        6
# Error in library(BayesFactor) : there is no package called ‘BayesFactor’
# /usr/local/lib/python2.7/dist-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Error in library(BayesFactor) : there is no package called ‘BayesFactor’
#
#   warnings.warn(x, RRuntimeWarning)
